# %%
# %%capture

# !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft trl triton cut_cross_entropy unsloth_zoo
# !pip install sentencepiece protobuf "datasets>=3.4.1" huggingface_hub hf_transfer
# !pip install --no-deps unsloth

# %%
from google.colab import userdata
import os

os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN") # Create a token at https://huggingface.co/settings/tokens

# %%
import json
import torch
from unsloth import FastModel
from datasets import load_dataset

model, tokenizer = FastModel.from_pretrained(
    model_name="lukepramo221/gemma-3-4b-finetuned_choreo-qna_full_v0.1",
    max_seq_length=2048,
    load_in_4bit=True,
    token=os.environ["HF_TOKEN"]
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.6.11: Fast Gemma3 patching. Transformers: 4.52.4.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: Using float16 precision for gemma3 won't work! Using float32.
# model.safetensors:   0%|          | 0.00/4.56G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/210 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/670 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# processor_config.json:   0%|          | 0.00/70.0 [00:00<?, ?B/s]
# chat_template.json: 0.00B [00:00, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/59.7M [00:00<?, ?B/s]

# %%
dataset = load_dataset("lukepramo221/gemma-3-4b-finetuned_choreo-qna_full_v0.1", split="test", token=os.environ["HF_TOKEN"])
output_file_path = 'output.jsonl'
results = []

for data in dataset:
    question = data.get("question")

    if not question:
        continue

    messages = [{
        "role": "user",
        "content": [{"type" : "text", "text" : question}]
    }]

    prompt_text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True,
    )

    inputs = tokenizer([prompt_text], return_tensors="pt").to("cuda")

    outputs = model.generate(
        input_ids=inputs["input_ids"],
        max_new_tokens=256,
        temperature=1.0,
        top_p=0.95,
        top_k=64,
        do_sample=True
    )

    generated_text = tokenizer.batch_decode(outputs[:, inputs["input_ids"].shape[-1]:], skip_special_tokens=True)[0]
    print(generated_text + '\n')
    new_data = data.copy()
    new_data['finetuned_answer'] = generated_text.strip()

    results.append(new_data)

with open(output_file_path, 'w') as outfile:
    for entry in results:
        outfile.write(json.dumps(entry) + '\n')

print(f"Processing complete. Output written to {output_file_path}")
# Out:
# README.md:   0%|          | 0.00/214 [00:00<?, ?B/s]
# choreo_concepts_qna_test_set.jsonl: 0.00B [00:00, ?B/s]
# Generating test split:   0%|          | 0/166 [00:00<?, ? examples/s]
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# You have set `compile_config`, but we are unable to meet the criteria for compilation. Compilation will be skipped.
# Choreo supports the standalone deployment of each part (component) of your application, allowing each to be deployed and made live individually.
#
# Updates, including security patches and bug fixes, are managed for software components in a private data plane via the organization's central update management system.
#
# To set up this pipeline, go to the 'Deploy' page of your component, choose a compatible environment from the 'Set Up' card, and then activate the 'Auto Build on Commit' option. For deployment, utilize the 'Deploy on Commit' option directly on the component's 'Deploy' page, or leverage the 'Deploy' card for scheduled deployment.
#
# To this end, simply provide your custom Dockerfile name as a unique value in the 'BuildSettings' section of your Choreo project. This will instruct Choreo to build your container images using the specific steps outlined in that Dockerfile.
#
# The recommended process is to manually trigger a promotion of the container image to the `production` environment following the service's successful completion of automated tests in the `stagin` environment.
#
# The 'Choreo DevOps' role is directly supported by and works in collaboration with the 'Choreo Platform Engineer' role.
#
# Environments in Choreo are dedicated areas for running your applications, and yes, you can customize them to suit your specific needs.
#
# When a new minor version is released for a service in the Marketplace, its description will automatically update to include this new minor version, maintaining a historical record of previous minor versions.
#
# Under the Choreo model, your Python microservice will be housed within a dedicated Kubernetes pod. This means resources are allocated on an isolated basis, with no shared resources between different components.
#
# Project Connections utilize OAuth for security, and its security is maintained when shared across all dependent components of an application.
#
# To get added to the Choreo Marketplace, services need to be structured as Choreo services.
#
# Yes, if the `v1` `ShippingAPI` service is configured with flexible version matching (e.g., `v1...`), it is designed to automatically start using the latest available minor version when a new one is released. In this specific example, upon `v1.3` being released, the `v1` `ShippingAPI` service in your Choreo development environment would automatically adjust to `v1.3`.
#
# In Choreo, a component is a distinct, manageable work item within a cloud-native application. It typically encompasses a single microservice, an API interface, or a defined batch job/task.
#
# You can configure environment-specific variables by integrating external API keys or access tokens through variable maps that are defined at the component level. These maps are then resolved into specific values for each environment, ensuring the container has the necessary credentials when running in production.
#
# You can deploy the Docker image by accessing the 'Deploy' button located in the component's settings. This will initiate a manual deployment process.
#
# You should use Deployment Tracks to create specialized, organized pathways for software components, making the process of getting them deployed much easier and more efficient. They provide key benefits such as facilitating straightforward management of different component types, ensuring robust and consistent deployments, and optimizing the placement of components across various environments.
#
# The 'build once, deploy many' strategy in Choreo means that a specific version of the application is built just once. This single, standalone build is then made available for deployment to all environments (e.g., development, QA, production) with minor adjustments or configurations as needed.
#
# To find services in the Choreo Marketplace, utilize the search bar located on the platform. You can also refine your search by applying various filter options available on the left-hand side.
#
# Choreo supports various component types, including services, API proxies, integrations, and web applications.
#
# Yes, every different project in Choreo has the capability to define and employ a unique configuration of environments.
#
# The Choreo Marketplace offers filtering options categorized as 'Category' and 'Label'. Additionally, a 'Filter All' option is provided to reset the current filtering settings and display the entire set of available services.
#
# Choreo offers a set of pre-defined user groups to accommodate various roles: admin, API developer, DevOps, IT ops, Frontend developer, Full stack developer, Backend developer, UI designer, UX writer, and QA engineer.
#
# To achieve this, I would recommend configuring your Choreo `production` environment to utilize multiple Kubernetes clusters for your Java Spring Boot application, ensuring high resilience and resource efficiency.
#
# Absolutely, you can set up a `staging` environment in Choreo for your Java Spring Boot microservice. To configure this, activate multi-environment support for your project by accessing 'Project' → 'Settings' from the header of the component where it is hosted, then under the 'Deploy' tab, choose 'Deploy all'. Subsequently, when deploying to the environment, select 'Set up environment' and then follow the instructions to establish the new environment.
#
# The primary role of the Choreo control plane is to provide the framework for component management, encompassing all aspects from their initial creation and deployment to their ongoing supervision and economic optimization.
#
# To deploy your new Node.js microservice to a particular development environment within your Choreo project, simply navigate to the 'Deploy' section of that component, complete the necessary settings on the chosen environment, and then initiate the deployment process.
#
# Choreo's system enforces API versioning by appending a -v version attribute to each API resource. This approach simplifies handling of multiple API versions. For example, if your API is named 'v1', Choreo will automatically expose 'v1 - development' and 'v1 - production' as distinct APIs. If a new minor version (e.g., v1.2) is released, 'v1 - development' will become 'v1 - development' (v1.2) and 'v1 - production' will be 'v1 - production' (v1.2). This method ensures that the older API versions remain accessible while newer iterations are deployed, maintaining a robust API lifecycle for your component.
#
# You can find your organization's unique ID by following these steps:
# 1. Navigate to https://console.choreo.dev/ and log into your account.
# 2. In the top right corner, click on 'Organization' and select the specific organization you want to get the ID for.
# 3. On the left side of the screen, select 'Settings'.
# 4. Within the settings page, look for and click on the 'Organization' section or section header.
# 5. The Organization ID will be displayed, and you can click the 'Copy ID' button next to it to retrieve it.
#
# When you opt for the 'Customer self-managed' model, WSO2 handles the management of all backend infrastructure, including updates and security patches. You, as the customer, are responsible for the operational aspects of the platform, including the continuous monitoring of logs, and administering user identities and their associated security roles.
#
# The changes you've made to the `UserManagement` service component's description and network visibility within Choreo will auto-reflect in the Choreo Marketplace. No manual update is required.
#
# Changing configurations after a component is deployed will lead to the component being re-deployed with the new configurations.
#
# Choreo handles the infrastructure by provisioning a new Kubernetes cluster for each development environment, which is then unified into a single namespace. Data planes, however, are not clustered; they are dedicated exclusively to the organization, even though the compute resources (nodes) are shared across all environments via this single cluster.
#
# To deploy your Python Flask microservice as a component in Choreo, you need to:
# 1. Merge a repository containing only the source code for the service into the main repository.
# 2. Configure Choreo to recognize this specific directory as the repository to pull the service's code from.
# 3. Let Choreo handle the automatic build and deployment of the service when the repository is watched.
#
# You can deploy the React frontend as a public endpoint to Choreo's hosting platform, making it globally accessible. For the internal administrative API, deploy it as an internal API within Choreo, restricting its access to the organization's members.
#
# You should use a Project Connection when you want to establish a connection that is solely and specifically for a particular project. For example, a Project Connection might be set up to interact with Twilio, and this is limited solely to the operations of that particular project.
#
# You can only create more than one organization if you possess organization membership privileges. As for joining multiple organizations, Choreo does not support this; membership is exclusive to one organization.
#
# Absolutely, you've nothing to lose by utilizing Deployment Tracks; they are designed for seamless integration with existing CI workflows, making them perfectly viable for CD-only scenarios like yours.
#
# The benefits of using Choreo's Connections for integration are several: they simplify service consumption by managing all connections, they guarantee secure and consistent service access through strategic application, and they foster a well-structured and organized approach to connecting to various services.
#
# To track patch updates and other internal versions for your API service component in Choreo, you need to configure multiple API versions using the major and minor version parameters. This will give your service component the necessary functionality to handle requests coming in with different patch-related versions.
#
# You can perform tasks like controlling the operational lifespan (lifecycle) and configuring its security measures for an individual endpoint in Choreo's API management system.
#
# Choreo's Cloud Spout architecture, with its apex scalable infrastructure, is ideal for hosting your React SPA. The deployment process differs from backend APIs in that it's a direct streaming push to your chosen container registry, rather than traditional Docker build and push.
#
# When exploring a service in detail, you can see its overview, accompanying documentation, implemented API definitions, and detailed usage instructions.
#
# To deploy an image in Choreo, navigate to the 'Deploy' section and enter a container name, source (e.g., a Git repository or a Docker registry repository), and optional environment parameters. You can then activate 'Auto Build and Deploy' to automate the process of building a container from a provided Git commit automatically and deploying it to the set-up environment.
#
# The initial deployment step is to trigger a build and deploy the service manually. Once this is done, you'll gain the ability to automate all subsequent builds and deployments by clicking the 'Build and Deploy' button on the component's 'Deploy' card.
#
# You can deploy a Choreo private data plane (PDP) in virtually any environment that supports containerization, encompassing leading public cloud providers like AWS, Azure, and GCP, as well as private, on-premise data centers.
#
# When you initially use Choreo, the very first step is to create an account. Once that's done, you'll be able to set up your personal workspace. Yes, you can indeed create multiple workspaces within Choreo, and each can be dedicated to a distinct project.
#
# You can find the Organization Handle by going to the 'Settings' page within your Choreo session, navigating to the 'Organization' area, and subsequently clicking 'Regenerate Handle'.
#
# Deployment Tracks handle API versioning for service components by supporting both major version advancement and the introduction of patch-level updates.
#
# Yes, each component type in Choreo is characterized by and offers unique features based on its specific role and design.
#
# Environment-independent configurations are identical for every environment, while environment-specific settings vary by environment. To manage them, you're provided with tools to easily pull up the correct configuration values based on the current environment.
#
# The Choreo control plane is typically interacted with by roles such as CIOs, architects, developers, DevOps personnel, site reliability engineers, and platform engineers.
#
# No, after deploying a new `UserAuthentication` service component to its initial environment, it is automatically discoverable in the Choreo Marketplace within 30 minutes.
#
# In the context of Choreo, an Endpoint is a function that is made available for network access. It's typically defined on a particular component within the system.
#
# A Choreo 'Project' in the Cell-based architecture aligns directly with a 'Cell'. Both are designed to be self-contained units that manage a collection of like-minded components.
#
# Yes, you can edit or update service information in the Choreo Marketplace as long as the service is currently active and operational.
#
# Choreo handles API management by applying settings to the component level. This allows for the management of each endpoint as a distinct API, which is exactly the feature you requested.
#
# Choreo simplifies multi-cluster deployments by offering the ability to deploy applications across multiple environments with just a single click, thereby optimizing resource utilization and enhancing resilience.
#
# The architecture of Choreo is built upon two main parts: the control plane and the data plane.
#
# Choreo's core software components, when deployed via Helm on your Kubernetes infrastructure, encompass the API Gateway, Zuul (gateway proxy), observability and logging APIs (combing APIs like APIs for observability data, log data, and API traffic), and the agent component.
#
# You should add them to the 'API Developers' group to ensure they have the necessary permissions.
#
# System components are installed within a namespace in Kubernetes, a platform that is part of the Choreo private data plane.
#
# You can securely store your external API key as a environment variable within Choreo. The injection of this key at runtime will then be facilitated by Flask's environment variable lookup mechanism.
#
# Yes, Component Connections offer an automatic way to handle OAuth for multi-Choreo service consumption, simplifying authentication.
#
# Environments in Choreo are defined, isolated areas within a data plane for running user applications. They are typically created by subdividing a single data plane into multiple distinct environments.
# Print: N/A
# Total: N/A
#
# To configure auto-deployment on pull request merges, follow these steps: First, go to your project's 'Deploy' page and click 'Deploy' to set up Choreo. Then, associate your GitHub organization with the chosen Choreo component. Afterward, enable the 'Auto Deploy on Pull Request' option under the 'Deploy' section, specifying the target branch (e.g., 'main') for the automatic deployments.
#
# Yes, Choreo recommends using a single GitHub repository to house all components within a project, enforcing a polyrepo strategy.
#
# In the context of Choreo, Deployment Tracks are designated, organized pathways crafted to simplify the deployment of software components. They perform a role similar to enhanced CI/CD workflows, ensuring the seamless transfer of components to their final destinations across various environments. Their primary goal is to establish a well-structured and systematic methodology that effectively reduces potential errors and difficulties commonly associated with software deployments.
#
# Setting up a Choreo private data plane on an existing cloud infrastructure like Azure, AWS, or GCP requires you to have configured VMs, defined networking, established storage, and established a cron schedule for backups.
#
# Choreo provides two distinct data plane types: the cloud data plane and the private data plane (PDP). The cloud data plane is a shared, multi-tenant infrastructure where user applications and services run within a secured environment alongside other users' applications. Conversely, a private data plane (PDP) is an exclusive, single-tenant infrastructure specifically designed and executed for a solitary organization's applications and services, ensuring a heightened level of privacy and tailored control.
#
# Choreo features a robust system of roles, each designed to grant users specific capabilities. Here's a breakdown of the primary roles:
# - **Admin:** A user with full, comprehensive access to manage the platform, configure settings, handle users, and oversee all aspects of Choreo.
# - **API Publisher:** This role is for users who want to make their APIs available for consumption by others. They can manage the publishing and visibility of their APIs.
# - **API Subscriber:** This role is for users who want to access and integrate with APIs for their applications or services.
# - **Billing Admin:** This role is exclusively for managing all billing-related functions and invoicing within Choreo.
# - **Choreo DevOps:** This role is designed for users who need to manage the entire DevOps workflow, including but not limited to continuous integration, continuous delivery, and environment management.
# - **Developer:** This role is for individuals who build, deploy, and manage cloud-native applications and services on Choreo.
# - **External API Subscriber:** This role is for subscribers whose APIs are accessed from outside the internal Choreo ecosystem.
# - **Internal API Subscriber:** This role is for subscribers whose APIs are accessed within the internal Choreo ecosystem.
# It's important
#
# Choreo achieves this by creating a dedicated data plane for each application, limiting its network traffic exclusively to itself, thereby ensuring security and containment.
#
# Yes, you can associate multiple Kubernetes clusters with a single environment in Choreo. This is typically done to build solutions that are inherently resilient and designed to operate across a network of clusters.
#
# The best approach is to create a Choreo environment variable named `TWILIO_API_KEY` and `TWILIO_API_SECRET` and reference them in your Python code. This method ensures that the Twilio client will use the values attached to the environment variables, making the application adaptable to different operational environments and requiring no modification to the service's code for Twilio-related configurations.
#
# Yes, there are special considerations for deploying Ballerina components, primarily due to the necessity of having a Choreo environment configured with both the appropriate runtime version and the necessary security policies.
#
# Components within a Choreo project are deployed as containers within the user-defined namespace of the Kubernetes cluster.
#
# Choreo ensures all network traffic for private data plane applications is secured through a dedicated cluster of outbound-facing APIs, managed entirely within the Choreo environment. This also covers all internal communications.
#
# I'd recommend selecting the scheduled integration component type for your daily data synchronization job. To configure it to run every day at a specific time, you'll find the necessary settings on the 'Deploy' page of the component, within the component's specific 'Settings' section.
#
# For effective communication, your Choreo private data plane requires outbound whitelisting for the following endpoints and protocols: the Choreo control plane's public API (specifically `https://console.choreo.dev/`) and any other external services enabled within the Choreo console.
#
# Components can be exposed in three distinct ways: as standalone services, as integrated API proxy-for-proxy integrations, or as part of a dedicated Choreo API product.
#
# You can find the build logs by accessing the 'Build' section of the component details page. Specifically, the unsuccessful build's information will be displayed, allowing you to view its logs.
#
# You can find more detailed instructions on configuring endpoints in Choreo's component development context by referencing the 'Configure Endpoints' document found at `../develop-components/configure-endpoints.md`.
#
# To handle patch updates or internal version tracking, Choreo suggests leveraging the 'X.Y.Z' versioning scheme, where X is the major version, Y is the minor version, and Z is an internal version identifier.
#
# Service versions in the Choreo Marketplace are managed following the Semantic Versioning convention. This means each service entry will have a major version, a minor version, and a specific build number.
#
# To establish secure and efficient inter-service communication, `OrderService` should make requests to `PaymentService`'s `/payment/status` endpoint, leveraging the `HETIC` communication type, which stands for "Heuristic Inter-Service Traffic Engineering". This method, implemented by Choreo, ensures a intelligent, optimized routing of traffic solely to the active instances of `PaymentService`, resulting in a stronger cache-friendly pattern.
#
# The appropriate role for your external partner is the 'API Consumer' within your Choreo organization. This role specifically grants them the necessary permissions to consume APIs without any access to development or publishing capabilities.
#
# Yes, a Choreo project aligns with the architectural pattern of a 'cell', specifically, a 'reference cell'.
#
# An organization in Choreo is a defined structure designed to aggregate users and their associated resources. It's fundamentally important for new users because it provides this essential structure for organizing their users and their data.
#
# To associate your GraphQL SDL with an endpoint in Choreo, simply link it by accessing the 'component''s relevant 'endpoint' object and injecting the SDL as the 'resolution' parameter.
#
# Choreo will expose the endpoints of your microservice in a format known as hHal, which is a machine-readable representation of your services and their endpoints.
#
# In the context of Choreo, a 'project' is a highly organized assemblage designed to encapsulate a single cloud-native application. Its chief aim is to provide an environment that unites a set of associated components, allowing for their seamless deployment and execution as a unified application.
#
# Choreo ensures configurations and secrets are handled securely across environments by keeping them separate from the service logic, which guarantees their security and integrity.
#
# Once a connection is established in Choreo for a service, you can access it by going to the 'Connections' list within that service's dedicated component. From there, you'll find the necessary connection ID, which users can then employ to create the required connection within their development environment.
#
# Data privacy and compliance are maintained through the storage of logs and observability data within the data plane's native storage, ensuring an organization's data remains exclusively within its environment.
#
# To connect your Choreo-deployed Node.js microservice to the external AWS RDS PostgreSQL database, you'll need to obtain the service connection parameters, including the connection string, via the Choreo Console. The service allows you to assign a user name and a specific role to the service, which will then be granted administrative privileges within the database.
#
# Choreo ensures this by strictly confining all logs and observability data generated by your application's runtime exclusively to your private data plane, meaning it stays within your borders.
#
# It is more appropriate to use a Component Connection when your objective is to link a historical or legacy service specifically and directly to one particular component.
#
# To deploy a component to an environment in Choreo, you need to select the environment from the 'Deploy' page of the component, click the 'Deploy' button within the specific environment's dropdown menu, and then wait for the deployment process to finish.
#
# To redeploy the older service version in Choreo, simply go to the 'Deploy' page for that service, use the 'Set Up' card to deploy it with the required Git commit. This will deploy the exact service version that was built from that specific commit, resolving to the version you need.
#
# For connecting to this isolated, on-premise legacy service, the recommended connection type in Choreo is a service connection. This targeted approach ensures that the Go microservice's dependencies are explicitly tied to the legacy SOAP service, without introducing unnecessary network openness.
#
# To monitor execution, go to 'Settings -> Operations', find the 'History' tab, and activate 'Turn on History'.
#
# Choreo provides environment variables as a means to manage these different database connection string configurations.
#
# Essential infrastructure includes upwards-compatible compute instances, durable storage for data and associated files, and a robust network configured for secure inbound and outbound communication.
#
# A Choreo project can include a maximum of 50 components.
#
# Absolutely, you can integrate unit tests into the build process by configuring your build scripts to execute them.
#
# The configuration to associate an OpenAPI definition with your Go microservice's exposed endpoints can be found within the 'Manage → Endpoints' area of the Choreo platform, specifically under the component's settings.
#
# To switch between organizations, simply find and select the appropriate organization from the 'Organization' dropdown menu, which is visible within the scope of that particular organization.
#
# You can view the logs for your builds by visiting the 'Build' page for that specific build.
#
# You can view the API contract for a given `PaymentGatewayService` by accessing its 'View API' page within the Marketplace. This specific page will also provide a 'Get API specification' option, which is what you need to fetch the OpenAPI specification as a response.
#
# To specify the API version consumers will see, simply link it to a particular API version attribute present in your component's 'Manage -> Deploy' page.
#
# Choreo offers a streamlined solution for deploying a monorepo with multiple languages/frameworks by treating the entire repository as a single project. This approach enables efficient resource sharing and optimized deployment of all components within a unified application.
#
# To get Choreo to build your component using your custom Dockerfile, simply label the deployment unit for that component as `frombuild`. Choreo's system will then execute the `build` phase using the Dockerfile you provided in the `forgit` file.
#
# To get your Organization ID:
# 1. Go to https://console.choreo.dev/ and sign into your account.
# 2. Confirm that you've selected the correct organization from the 'Organization' list in the header.
# 3. In the left sidebar, navigate to 'Settings'.
# 4. On the 'Settings' page, look for the 'Organization' information and click 'Copy ID' to retrieve it.
#
# The decision depends on the critical need for data privacy and control. A Choreo private data plane is ideal if you want to guarantee your data remains exclusively within your organization's environment. For most organizations, a cloud data plane offers adequate privacy and control, facilitated by collaborative security measures.
#
# To populate the 'Overview' section with information for the Marketplace, you must reference your service's functionality. You can add additional related documents by uploading them as separate documents within the 'Related Docs' tab of the Marketplace entry.
#
# Choreo offers three primary management models for private data planes (PDPs): 1) A WSO2-operated model where the infrastructure and PDP are provisioned and managed by WSO2. 2) A WSO2-operated model where the infrastructure and PDP are provisioned and managed by WSO2, but with the customer having additional customization options for the underlying configurations. 3) A customer-operated model where WSO2 supplies the necessary installation scripts and updates, and the customer is responsible for all aspects of provision and management.
#
# Yes, immediately following the promotion of a component to the initial environment, users have the capability to promote its image to subsequent environments.
#
# Yes, Choreo enables you to manage and scale each part of your application, defining separate environments for doing so.
#
# You can find specific instructions on how to connect to and consume the `NotificationService` in the Marketplace by accessing the 'Use' or 'Integrate' card located in the Marketplace interface.
#
# A standard Choreo build pipeline includes automated steps for building, testing, and deploying a container image.
#
# Yes, it is entirely possible and often necessary to define and use distinct configurations for a given component in two or more environments.
#
# No, you are not required to use a distinct Kubernetes cluster for every environment. A pragmatic solution involves leveraging only one Kubernetes cluster by creating multiple environments within it.
#
# To efficiently switch between environments, simply use the search bar in the Choreo Console's header. This will allow you to rapidly jump to the necessary environment for every client.
#
# Components are deployed into a project's runtime environment, falling under its associated organization.
#
# Yes, the private data plane needs to communicate with the Choreo control plane via HTTPS. All traffic from the private data plane to the control plane is outbound.
#
# To verify the visibility of the new `CustomerData` service in the Marketplace, go to https://console.logz.dev/marketplace, search for it, and then access its 'Settings' page to confirm its visibility settings.
#
# To filter the Marketplace and see only internally deployed services by your team, use the 'Internal' filter option found on the left-hand side of the Marketplace page.
#
# You should assign their user accounts to the 'Billing Admin' role or create a dedicated group with identical permissions.
#
# You can find your organization's handle by going to https://console.choreo.dev/settings/organization on your Choreo console.
#
# To achieve this, you'll configure the GoLang worker to listen on a dedicated internal socket endpoint within the Choreo environment. This method of limiting access is the sole responsibility of the Go Lang component, ensuring its services are not globally accessible.
#
# At runtime, your application code will find the configured Choreo Connection parameters as environment variables within the environment. It will then use these environment variables to programmatically obtain the necessary values for establishing the connection.
#
# A Choreo data plane is essentially a set of interconnected data plane nodes. It's designed to be a robust platform for deploying both batch and edge-to-cloud streaming applications.
#
# You should increment the major version when you introduce capabilities that are incompatible with previous API iterations.
#
# Project Connections are designed to establish links with services within a specific project. Instead hand, Component Connections allow for connections to resources within the very same project.
#
# Moving your API to production in Choreo involves conducting a final deployment within the 'Set Up' section of the component. This action will trigger a cascade, applying the new configurations and code specifically for the production environment, and leveraging the designated production database credentials.
#
# You can find a specific internal API by entering its name or a relevant keyword in the 'Search' field located on the Choreo Marketplace's home page. This will display all APIs that match the criteria, allowing for efficient navigation to the desired resource.
#
# To promote a component, navigate to its 'Deploy' page, utilize the 'Set Up' section to initiate a deployment specifically for the target environment (for example, production), and then trigger the actual promotion by clicking the 'Promote' button.
#
# By default, Choreo provides development and production environments, with the ability to create additional custom environments as needed.
#
# In the context of Choreo, a group is essentially a collection of users, with individual users being associated with one or multiple such collections. Users inherit permissions directly linked to the specific group they are part of.
#
# By default, new Choreo projects configure three environments: development, production, and staging. Your project is automatically associated with these environments upon project creation. You can, of course, adapt or add environments to fit your specific operational needs.
#
# Choreo believes in a seamless, modern CI/CD workflow that empowers developers to launch applications and services with remarkable agility.
#
# Absolutely, Choreo allows for the integration of your unit tests into its build pipeline. This is facilitated by creating a specific build artifact that contains your source code and its associated test files.
#
# Connections in Choreo are established links to services, other applications, or internal data stores. They are typically structured with specific connection parameters. You would use them to bridge the gap between your Choreo services/applications and external cloud services, other services within the ecosystem, or persistent data storage solutions.
#
# The 'Admin' role in Choreo encompasses comprehensive administrative capabilities. While managing users is a key function, users with this role also gain the ability to handle project creation, configure analytics parameters, and manage domains.
#
# Considering the recent changes, you should assign your team member the 'Choreo DevOps' role for the deployment, monitoring, and reliability aspects.
#
# Choreo expects the code or build instructions for a component to be present in a directory named `component.yaml` located within a repository's `src` folder.
#
# Yes, providing a service contract is mandatory for an endpoint in Choreo. If you don't, the endpoint will not be made available for public consumption.
#
#
# The `v1` entry in the Choreo Marketplace corresponds to the `v1.X` series (where X is either `1` or `2`), and the `v2` entry corresponds to the `v2.X` series (where X is `0` or `1`).
#
# To trigger a build, go to the 'Build' page and click 'Build Latest'. For automation, enable 'Auto Build on Commit' to build a container for every GitHub commit. You also have the option to configure specific build triggers for each branch.
#
# You can find the promotion option right after a successful build. The 'Deploy to Production' card contains a 'Promote' button. Using this button will trigger the automated build process for the environment they've chosen, which is production.
#
# Setting up a Choreo private data plane leads to the installation of `Choreo API Gateways`, `Choreo PDP`, `Choreo Control Plane`, and `Choreo API Discovery` components.
#
# Yes, Choreo offers this specific level of granularity, allowing you to define authentication policies on an endpoint-by-endpoint basis.
#
# You can search the Marketplace by entering a service name, a keyword, or by picking a specific cloud platform.
#
# Choreo manages user permissions by leveraging predefined roles and associated permissions.
#
# To move your components, simply navigate to the environment you wish to associate them with from the 'Deploy' screen.
#
# For GitHub-based projects, Deployment Tracks integrate seamlessly into the entire CI/CD pipeline, facilitating automated deployments to respective environments.
#
# The Choreo Marketplace is a digital marketplace designed to enable and simplify the sharing and reuse of services. Its main purpose is to provide a platform where users can list their deployed services for others to effortlessly find and utilize.
#
# 'Repeatable builds' in Choreo refer to the guarantee that a build initiated for a specific commit will always result in a Docker image with identical runtime characteristics if deployed with that same label.
#
# You can increase the capacity of the API service component on Choreo manually by accessing the 'Manage → Deploy' page, making necessary adjustments within the 'Set Up' card, and then triggering a new deployment.
#
# The Choreo private data plane leverages encryption for all traffic and data, is protected by a robust firewall, and features authentication and authorization controls managed by the API Gateway.
#
# Absolutely, during all deployment and promotion operations, Choreo is configured to use rolling updates, ensuring continuous operation for your application.
#
# Yes, you can streamline this by configuring a single OAuth application for both Choreo services consumed by the component. This way, your C# component will use the same client ID and secret to access both services, leveraging a combined OAuth application.
#
# Yes, all multiple microservices deployed in a single Choreo project will share the same Kubernetes namespace. For network communication, this means that the Python Flask API can directly access the Node.js authentication service via the Internet Protocol (IP), and the Node.js authentication service can directly access the Python Flask API via the IP. This cross-service network access is a consequence of their co-location within the unified namespace.
#
# Absolutely, Choreo supports the co-deployment of multiple application types and languages, like the examples you mentioned, all on a single data plane.
#
# You can host `development` and `staging` (and other environments) on the *same* Choreo Kubernetes cluster. The critical aspect is that each environment will reside within a distinct namespace of the single cluster.
#
# Choreo guarantees uninterrupted API access by setting up a new deploy stage that points to the updated backend. This ensures that traffic is smoothly redirected to the latest and greatest stable version of your API, with no gaps in service.
#
# Data planes in Choreo are configured as 'cells', which are designed to be tightly secured and isolated from other environments. Access is granted only to the services and users specifically associated with that cell.
#
# Processing complete. Output written to output.jsonl

# %%
from google.colab import files
files.download('output.jsonl')
